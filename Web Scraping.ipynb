# %% [markdown]
# API Key: U4XHL332J7SFF57W

# %%
# !pip install alpha_vantage
# Out:
# Collecting alpha_vantage
#   Using cached https://files.pythonhosted.org/packages/7a/6c/81c7f1c58064cb2ce808edc6c4cdb3241f70bf8cd158289540cdf9fe0204/alpha_vantage-2.1.0.tar.gz
# Requirement already satisfied: requests in /anaconda3/envs/learn-env/lib/python3.6/site-packages (from alpha_vantage) (2.19.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests->alpha_vantage) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests->alpha_vantage) (2019.6.16)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests->alpha_vantage) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests->alpha_vantage) (2.7)
# Building wheels for collected packages: alpha-vantage
#   Building wheel for alpha-vantage (setup.py) ... done
#   Stored in directory: /Users/abajpai/Library/Caches/pip/wheels/21/9c/02/b7cfae63f7119f4089f229ba1a09ce90fabbaf96199c2890be
# Successfully built alpha-vantage
# Installing collected packages: alpha-vantage
# Successfully installed alpha-vantage-2.1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(15,10)})

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='U4XHL332J7SFF57W', output_format='pandas')
# Get json object with the intraday data and another with  the call's metadata
data, meta_data = ts.get_intraday('RES')

# %%
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2019-07-18 13:30:00   6.0000    6.020  5.9900    5.9950    27591.0
# 2019-07-18 13:45:00   5.9900    6.040  5.9900    6.0150    51863.0
# 2019-07-18 14:00:00   6.0127    6.030  5.9700    6.0243    46135.0
# 2019-07-18 14:15:00   6.0250    6.050  5.9800    5.9900  1356985.0
# 2019-07-18 14:30:00   5.9900    6.000  5.9700    6.0000    32524.0
# 2019-07-18 14:45:00   5.9900    6.035  5.9750    6.0300    29523.0
# 2019-07-18 15:00:00   6.0350    6.040  5.9900    6.0300    74846.0
# 2019-07-18 15:15:00   6.0300    6.050  6.0100    6.0500    36781.0
# 2019-07-18 15:30:00   6.0450    6.090  6.0400    6.0850    61651.0
# 2019-07-18 15:45:00   6.0800    6.120  6.0800    6.0900    67897.0
# 2019-07-18 16:00:00   6.0800    6.110  6.0800    6.1000   127699.0
# 2019-07-19 09:45:00   6.1500    6.160  6.0900    6.1600    60112.0
# 2019-07-19 10:00:00   6.1650    6.175  6.0450    6.0900    57350.0
# 2019-07-19 10:15:00   6.0900    6.110  6.0706    6.0800    49363.0
# 2019-07-19 10:30:00   6.0800    6.275  6.0750    6.2300   744941.0
# 2019-07-19 10:45:00   6.2350    6.255  6.1700    6.1800    44262.0
# 2019-07-19 11:00:00   6.1700    6.190  6.1500    6.1900    30696.0
# 2019-07-19 11:15:00   6.1900    6.210  6.1650    6.2100    61341.0
# 2019-07-19 11:30:00   6.2000    6.205  6.1550    6.1600    32256.0
# 2019-07-19 11:45:00   6.1600    6.170  6.1300    6.1600    48933.0
# 2019-07-19 12:00:00   6.1500    6.225  6.1500    6.2200    29078.0
# 2019-07-19 12:15:00   6.2200    6.225  6.1700    6.2000    21589.0
# 2019-07-19 12:30:00   6.2000    6.220  6.1800    6.1900    28855.0
# 2019-07-19 12:45:00   6.1800    6.240  6.1750    6.2200    31237.0
# 2019-07-19 13:00:00   6.2300    6.245  6.2100    6.2200    28579.0
# 2019-07-19 13:15:00   6.2200    6.260  6.2150    6.2600    28566.0
# 2019-07-19 13:30:00   6.2600    6.265  6.2400    6.2550    27734.0
# 2019-07-19 13:45:00   6.2600    6.310  6.2600    6.3100    52788.0
# 2019-07-19 14:00:00   6.3100    6.340  6.2800    6.3400    51033.0
# 2019-07-19 14:15:00   6.3400    6.350  6.3100    6.3400    60689.0
# ...                      ...      ...     ...       ...        ...
# 2019-07-23 11:30:00   6.5100    6.550  6.5050    6.5250    51690.0
# 2019-07-23 11:45:00   6.5200    6.530  6.5100    6.5100    30430.0
# 2019-07-23 12:00:00   6.5150    6.570  6.5100    6.5600    81746.0
# 2019-07-23 12:15:00   6.5750    6.620  6.5750    6.6050   134056.0
# 2019-07-23 12:30:00   6.6000    6.640  6.6000    6.6300    95357.0
# 2019-07-23 12:45:00   6.6400    6.670  6.6200    6.6450    85848.0
# 2019-07-23 13:00:00   6.6450    6.670  6.6350    6.6700    44307.0
# 2019-07-23 13:15:00   6.6700    6.670  6.5500    6.5650    68771.0
# 2019-07-23 13:30:00   6.5650    6.600  6.5400    6.6000    43259.0
# 2019-07-23 13:45:00   6.5950    6.620  6.5800    6.6200    55611.0
# 2019-07-23 14:00:00   6.6200    6.620  6.5800    6.5850    40596.0
# 2019-07-23 14:15:00   6.5900    6.590  6.5600    6.5800    57005.0
# 2019-07-23 14:30:00   6.5850    6.590  6.5700    6.5700    52548.0
# 2019-07-23 14:45:00   6.5700    6.625  6.5700    6.6100    47117.0
# 2019-07-23 15:00:00   6.6150    6.630  6.5900    6.6000    50844.0
# 2019-07-23 15:15:00   6.5900    6.630  6.5900    6.6300    58496.0
# 2019-07-23 15:30:00   6.6300    6.630  6.5750    6.5750    84920.0
# 2019-07-23 15:45:00   6.5750    6.630  6.5750    6.6100   124044.0
# 2019-07-23 16:00:00   6.6100    6.630  6.6100    6.6100   265143.0
# 2019-07-24 09:45:00   6.1000    6.200  5.9100    5.9100   529313.0
# 2019-07-24 10:00:00   5.9200    6.230  5.9150    6.2300   281445.0
# 2019-07-24 10:15:00   6.2250    6.250  6.0650    6.0950   260351.0
# 2019-07-24 10:30:00   6.0950    6.130  6.0300    6.1000   130607.0
# 2019-07-24 10:45:00   6.1100    6.170  6.1000    6.1450   103860.0
# 2019-07-24 11:00:00   6.1450    6.170  6.0800    6.1700    98661.0
# 2019-07-24 11:15:00   6.1600    6.180  6.1350    6.1350   203637.0
# 2019-07-24 11:30:00   6.1350    6.135  5.9900    5.9950   104219.0
# 2019-07-24 11:45:00   5.9900    6.005  5.9850    5.9900    76273.0
# 2019-07-24 12:00:00   5.9900    6.010  5.9900    5.9900    82059.0
# 2019-07-24 12:15:00   5.9900    5.990  5.9200    5.9200    56477.0
#
# [100 rows x 5 columns]

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'RES',
#  '3. Last Refreshed': '2019-07-24 12:15:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
data.columns
# Out:
# Index(['1. open', '2. high', '3. low', '4. close', '5. volume'], dtype='object')

# %%
sns.lineplot(x=data.index, y=data['4. close'])

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

ts = TimeSeries(key='U4XHL332J7SFF57W', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT', outputsize='full')
sns.lineplot(x=data.index, y=data['4. close'])
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
from alpha_vantage.techindicators import TechIndicators
import matplotlib.pyplot as plt

ti = TechIndicators(key='U4XHL332J7SFF57W', output_format='pandas')
data, meta_data = ti.get_bbands(symbol='MSFT', interval='60min', time_period=60)
data.plot()
plt.title('BBbands indicator for  MSFT stock (60 min)')
plt.show()

# %%
from requests import get
from bs4 import BeautifulSoup #import beautiful soup 
url = 'https://store.steampowered.com/' #website we will be scraping
response = get(url)
html_soup = BeautifulSoup(response.text, 'html.parser') #parse text
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
warning = html_soup.find_all(class_='page_content_ctn')
#print(len(warning))
warning
# Out:
# [<div class="page_content_ctn dark" data-usability-scroll="120" id="content_callout">
#  <div class="home_page_content">
#  <div class="more_content_title"><span>Keep scrolling for more recommendations</span></div>
#  <div class="more_content_desc">Below, you'll find a variety of titles that you may be interested in from categories across Steam</div>
#  </div>
#  </div>,
#  <div class="page_content_ctn dark" id="content_login" style="display: none;">
#  <div class="home_page_content">
#  <div class="more_content_title"><span>Looking for recommendations?</span></div>
#  </div>
#  <div class="home_page_content">
#  <div class="home_page_sign_in_ctn small">
#  <p>Sign in to view personalized recommendations</p>
#  <div class="signin_buttons_ctn">
#  <a class="btn_green_white_innerfade btn_border_2px btn_medium" href="https://store.steampowered.com/login/">
#  <span>Sign in</span>
#  </a>
#  <br/><br/>
#  						Or <a href="https://store.steampowered.com/join/">sign up</a> and join Steam for free					</div>
#  </div>
#  </div>
#  </div>,
#  <div class="page_content_ctn dark" id="content_out" style="display: none;">
#  <div class="home_page_content">
#  <div class="more_content">We're out of personalized recommendations for you right now</div>
#  <div class="more_content_desc">We can recommend some different titles once you've played more games.</div>
#  <br/>
#  <div class="more_content">Still looking for more? Check out a <a href="https://store.steampowered.com/explore/random/">random game</a>.</div>
#  </div>
#  </div>,
#  <div class="page_content_ctn dark" id="content_none" style="display: none;">
#  <div class="home_page_content">
#  <div class="more_content">We don't have any recommendations to show you here.</div>
#  <div class="more_content_desc">This might be an error, or it might be that you don't have any playtime on record.<br/>You can hit refresh, or come back once you've played a game.</div>
#  <br/>
#  <div class="more_content">Perhaps you'd like to check out a <a href="https://store.steampowered.com/explore/random/">random game</a>?</div>
#  </div>
#  </div>,
#  <div class="page_content_ctn dark" id="content_loading">
#  <div class="home_page_content more_content" id="LoadingContent">
#  <div class="LoadingWrapper">
#  <div class="LoadingThrobber">
#  <div class="Bar Bar1"></div>
#  <div class="Bar Bar2"></div>
#  <div class="Bar Bar3"></div>
#  </div>
#  <div class="LoadingText">Loading more content...</div>
#  </div>
#  </div>
#  </div>]

# %%
prices = html_soup.find_all('div', class_='discount_pct')
prices 
#print(len(warning)) #prints a list of all discounts
# Out:
# [<div class="discount_pct">-30%</div>,
#  <div class="discount_pct">-25%</div>,
#  <div class="discount_pct">-80%</div>,
#  <div class="discount_pct">-33%</div>,
#  <div class="discount_pct">-10%</div>,
#  <div class="discount_pct">-20%</div>,
#  <div class="discount_pct">-10%</div>,
#  <div class="discount_pct">-10%</div>,
#  <div class="discount_pct">-10%</div>,
#  <div class="discount_pct">-20%</div>,
#  <div class="discount_pct">-25%</div>,
#  <div class="discount_pct">-75%</div>,
#  <div class="discount_pct">-50%</div>,
#  <div class="discount_pct">-33%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-10%</div>,
#  <div class="discount_pct">-50%</div>,
#  <div class="discount_pct">-10%</div>,
#  <div class="discount_pct">-12%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-80%</div>,
#  <div class="discount_pct">-50%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-10%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-70%</div>,
#  <div class="discount_pct">-50%</div>,
#  <div class="discount_pct">-80%</div>,
#  <div class="discount_pct">-50%</div>,
#  <div class="discount_pct">-25%</div>,
#  <div class="discount_pct">-25%</div>,
#  <div class="discount_pct">-75%</div>,
#  <div class="discount_pct">-50%</div>,
#  <div class="discount_pct">-33%</div>,
#  <div class="discount_pct">-50%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-80%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-80%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-70%</div>,
#  <div class="discount_pct">-50%</div>,
#  <div class="discount_pct">-50%</div>,
#  <div class="discount_pct">-80%</div>,
#  <div class="discount_pct">-75%</div>,
#  <div class="discount_pct">-25%</div>,
#  <div class="discount_pct">-35%</div>,
#  <div class="discount_pct">-75%</div>,
#  <div class="discount_pct">-15%</div>,
#  <div class="discount_pct">-75%</div>,
#  <div class="discount_pct">-75%</div>,
#  <div class="discount_pct">-80%</div>,
#  <div class="discount_pct">-67%</div>,
#  <div class="discount_pct">-80%</div>,
#  <div class="discount_pct">-35%</div>,
#  <div class="discount_pct">-75%</div>,
#  <div class="discount_pct">-25%</div>,
#  <div class="discount_pct">-80%</div>,
#  <div class="discount_pct">-50%</div>]

# %%
html_soup.find_all('div', class_='discount_prices')
# Out:
# [<div class="discount_prices"><div class="discount_original_price">$49.99</div><div class="discount_final_price">$34.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$14.99</div><div class="discount_final_price">$11.24</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$6.99</div><div class="discount_final_price">$1.40</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$26.79</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$26.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$9.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$49.99</div><div class="discount_final_price">$39.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$14.99</div><div class="discount_final_price">$13.49</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$14.99</div><div class="discount_final_price">$13.49</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$24.99</div><div class="discount_final_price">$22.49</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$14.99</div><div class="discount_final_price">$11.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$19.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$19.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$59.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">Free</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$39.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$999.00</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$749.00</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$499.00</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$59.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">Free</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">Free</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">Free</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$19.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$39.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">Free</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$39.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">Free</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$59.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$19.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$1.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$999.00</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$9.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$749.00</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$26.79</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$13.19</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$19.99</div><div class="discount_final_price">$6.59</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$24.99</div><div class="discount_final_price">$22.49</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$27.99</div><div class="discount_final_price">$25.19</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$34.98</div><div class="discount_final_price">$30.86</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$19.79</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$11.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$34.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$39.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.98</div><div class="discount_final_price">$19.98</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$19.79</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$26.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$9.89</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$79.99</div><div class="discount_final_price">$23.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$7.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$59.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$19.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$19.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$9.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$19.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">Free To Play</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">Free</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$19.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_final_price">$39.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$26.79</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$13.19</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$19.99</div><div class="discount_final_price">$6.59</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$11.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$19.79</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$7.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$19.79</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$9.89</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$79.99</div><div class="discount_final_price">$23.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$7.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$19.99</div><div class="discount_final_price">$4.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$29.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$25.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$25.49</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$7.49</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$59.99</div><div class="discount_final_price">$14.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$5.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$19.99</div><div class="discount_final_price">$6.59</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$29.99</div><div class="discount_final_price">$5.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$39.99</div><div class="discount_final_price">$25.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$19.99</div><div class="discount_final_price">$4.99</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$14.99</div><div class="discount_final_price">$11.24</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$6.99</div><div class="discount_final_price">$1.40</div></div>,
#  <div class="discount_prices"><div class="discount_original_price">$19.99</div><div class="discount_final_price">$9.99</div></div>]

# %%
prices[0]
# Out:
# <div class="discount_pct">-30%</div>

# %%
dir(prices[0])
# Out:
# ['HTML_FORMATTERS',
#  'XML_FORMATTERS',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'descendants',
#  'encode',
#  'encode_contents',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'isSelfClosing',
#  'is_empty_element',
#  'known_xml',
#  'name',
#  'namespace',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parserClass',
#  'parser_class',
#  'prefix',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'select',
#  'select_one',
#  'setup',
#  'string',
#  'strings',
#  'stripped_strings',
#  'text',
#  'unwrap',
#  'wrap']

# %%
prices = html_soup.find_all('div', class_='discount_prices')
#warning.text
reg_price=[] # initializes list
disc_price=[]
for i in prices: #loop through prices
    i = i.text
    #print(i[:6])
    reg_price.append(i[:6]) #append the regular price to list
    if len(i)<=6: #if there isn't a second value, thre is no discount
        disc_price.append('No Discount')
    elif i == ('Free To Play'): #if it is free to play, we will write that in
        disc_price.append('f2p')
        print('f2p')
    else:
        disc_price.append(i[6:]) #just impute the last few digits if neither are true
# Out:
# f2p

# %%
disc_price
# Out:
# ['$34.99',
#  '$11.24',
#  '1.40',
#  '$26.79',
#  '$26.99',
#  'No Discount',
#  '$39.99',
#  '$13.49',
#  '$13.49',
#  '$22.49',
#  '$11.99',
#  '$14.99',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  '0',
#  '0',
#  '0',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  '0',
#  'No Discount',
#  '0',
#  'No Discount',
#  '$14.99',
#  '$14.99',
#  '$26.79',
#  '$13.19',
#  '$6.59',
#  '$22.49',
#  '$14.99',
#  '$25.19',
#  '$30.86',
#  '$19.79',
#  '$11.99',
#  'No Discount',
#  'No Discount',
#  '$19.98',
#  '$19.79',
#  '$26.99',
#  '$9.89',
#  '$23.99',
#  '$29.99',
#  '$7.99',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  '$29.99',
#  '$29.99',
#  'No Discount',
#  'No Discount',
#  'f2p',
#  'No Discount',
#  '$14.99',
#  'No Discount',
#  '$14.99',
#  '$14.99',
#  '$26.79',
#  '$14.99',
#  '$13.19',
#  '$6.59',
#  '$11.99',
#  '$19.79',
#  '$7.99',
#  '$19.79',
#  '$9.89',
#  '$23.99',
#  '$29.99',
#  '$29.99',
#  '$7.99',
#  '$4.99',
#  '$29.99',
#  '$25.99',
#  '$14.99',
#  '$25.49',
#  '$7.49',
#  '$14.99',
#  '$5.99',
#  '$6.59',
#  '$5.99',
#  '$25.99',
#  '$4.99',
#  '$11.24',
#  '1.40',
#  '$9.99']

# %%
len(reg_price)
# Out:
# 100

# %%
len(disc_price)
# Out:
# 100

# %%
disc_price
# Out:
# ['$34.99',
#  '$11.24',
#  '1.40',
#  '$26.79',
#  '$26.99',
#  'No Discount',
#  '$39.99',
#  '$13.49',
#  '$13.49',
#  '$22.49',
#  '$11.99',
#  '$14.99',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  '0',
#  '0',
#  '0',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  '0',
#  'No Discount',
#  '0',
#  'No Discount',
#  '$14.99',
#  '$14.99',
#  '$26.79',
#  '$13.19',
#  '$6.59',
#  '$22.49',
#  '$14.99',
#  '$25.19',
#  '$30.86',
#  '$19.79',
#  '$11.99',
#  'No Discount',
#  'No Discount',
#  '$19.98',
#  '$19.79',
#  '$26.99',
#  '$9.89',
#  '$23.99',
#  '$29.99',
#  '$7.99',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  'No Discount',
#  '$29.99',
#  '$29.99',
#  'No Discount',
#  'No Discount',
#  'f2p',
#  'No Discount',
#  '$14.99',
#  'No Discount',
#  '$14.99',
#  '$14.99',
#  '$26.79',
#  '$14.99',
#  '$13.19',
#  '$6.59',
#  '$11.99',
#  '$19.79',
#  '$7.99',
#  '$19.79',
#  '$9.89',
#  '$23.99',
#  '$29.99',
#  '$29.99',
#  '$7.99',
#  '$4.99',
#  '$29.99',
#  '$25.99',
#  '$14.99',
#  '$25.49',
#  '$7.49',
#  '$14.99',
#  '$5.99',
#  '$6.59',
#  '$5.99',
#  '$25.99',
#  '$4.99',
#  '$11.24',
#  '1.40',
#  '$9.99']

# %%
len(reg_price)
# Out:
# 100

# %%
name_list = [] #loop essentially does the same but for the names 
names = html_soup.find_all('div', class_='tab_item_name')
for i in names:
    print(i.text)
    name_list.append(i.text)
# Out:
# Monster Boy and the Cursed Kingdom
# Survivor Pass 4: Aftermath
# DATE A LIVE: Rio Reincarnation / デート・ア・ライブ 凜緒リンカーネイション HD / 約會大作戰
# Automachef
# Swords & Souls: Neverseen
# Nowhere Prophet
# Detective Girl of the Steam City
# GORN
# Streets of Rogue
# EARTH DEFENSE FORCE 5
# RED HOT VENGEANCE
# FINAL FANTASY XIV: Shadowbringers
# Valve Index VR Kit
# Valve Index Headset + Controllers
# Valve Index Headset
# F1® 2019 Anniversary Edition
# Spider-Man: Far From Home Virtual Reality
# Aperture Hand Lab
# Totally Reliable Delivery Service Beta
# My Friend Pedro
# Steel Division 2
# The Scream
# They Are Billions
# Bloodstained: Ritual of the Night
# Shattered Lights
# OCTOPATH TRAVELER™
# Cooking Simulator
# Trover Saves the Universe
# Kao the Kangaroo: Round 2
# Void Bastards
# Valve Index VR Kit
# Survivor Pass 4: Aftermath
# Valve Index Headset + Controllers
# Wolfenstein: Youngblood
# Fallout 4: Game of the Year Edition
# Grand Theft Auto V
# NieR:Automata™
# The Elder Scrolls V: Skyrim Special Edition
# DOOM
# Iratus: Lord of the Dead
# PLAYERUNKNOWN'S BATTLEGROUNDS
# Arma 3 Contact
# Iratus Supporter Bundle
# Wolfenstein II: The New Colossus
# Dishonored: Death of the Outsider - Deluxe Bundle
# Destiny 2
# FINAL FANTASY XIV: Shadowbringers
# Grand Theft Auto V: Premium Online Edition
# The Elder Scrolls V: Skyrim VR
# Monster Boy and the Cursed Kingdom
# Wolfenstein: The Two Pack
# Dishonored: Complete Collection
# RAGE 2
# Dishonored 2
# Total War: THREE KINGDOMS
# Tom Clancy's Rainbow Six® Siege
# FINAL FANTASY XIV Online
# Grand Theft Auto V - Criminal Enterprise Starter Pack
# RAGE 2
# Sid Meier's Civilization® VI: Gathering Storm
# LOVE³ -Love Cube-
# NEW LIFE
# Tech Corp.
# Wolfenstein: Cyberpilot International Version
# Wolfenstein: Youngblood
# School Owner
# 月圆之夜（Night of Full Moon）
# Mirador
# The Witch's Love Diary
# Those Who Remain
# Gun Crazy
# Encased: A Sci-Fi Post-Apocalyptic RPG
# SKYHILL: Black Mist
# Metropolisim
# Morphies Law: Remorphed
# Truck Driver
# Raiders of the North Sea
# Warhammer 40,000: Inquisitor - Prophecy
# RetroArch
# Sin Slayers
# Everreach: Project Eden
# Mighty Gunvolt Burst
# Crossroads Inn
# Biker Garage: Mechanic Simulator
# Farming Life
# Electrician Simulator
# Crystal Crisis
# Face Gasket for Valve Index Headset – 2 Pack
# Cat Quest II
# London Detective Mysteria
# Fallout 4: Game of the Year Edition
# Grand Theft Auto V
# NieR:Automata™
# PLAYERUNKNOWN'S BATTLEGROUNDS
# The Elder Scrolls V: Skyrim Special Edition
# DOOM
# Dishonored: Death of the Outsider - Deluxe Bundle
# Wolfenstein II: The New Colossus
# Dishonored 2
# The Elder Scrolls V: Skyrim VR
# Wolfenstein: The Two Pack
# Dishonored: Complete Collection
# RAGE 2
# RAGE 2
# Prey Digital Deluxe
# Fallout New Vegas Ultimate
# Sid Meier's Civilization® VI: Gathering Storm
# The Elder Scrolls Online - Elsweyr
# The Evil Within 2
# Hell Let Loose
# Fallout 4
# Fallout 4 VR
# Dishonored®: Death of the Outsider™
# The Elder Scrolls IV: Oblivion® Game of the Year Edition Deluxe
# Prey
# The Elder Scrolls Online - Elsweyr
# Fallout 3: Game of the Year Edition
# Bad North: Jotunn Edition
# Hero Siege
# The Elder Scrolls® Online

# %%
len(name_list)
# Out:
# 120

# %%
item_details = [] #places item details in a list
items = html_soup.find_all('div', class_='tab_item_details')
for i in items:
    print(i.text)
    item_details.append(i.text)
# Out:
#  Action, Adventure, Indie, Metroidvania
#
#
#  Adventure, Action, Massively Multiplayer
#
#
#  Anime, Visual Novel, Simulation, Sexual Content
#
#
#  Indie, Simulation, Funny, Puzzle
#
#
#  RPG, Action, Adventure, Indie
#
#
#  Strategy, RPG, Card Game, Turn-Based
#
#
#  RPG, Indie, Sexual Content, Female Protagonist
#
#
# VR Only VR, Violent, Gore, Action
#
#
#  Rogue-like, Pixel Graphics, Rogue-lite, RPG
#
#
#  Action, Third-Person Shooter, Online Co-Op, Aliens
#
#
#  Free to Play, Indie, Violent, Gore
#
#
#  Massively Multiplayer, RPG, Fantasy, MMORPG
#
#
#
#
#
#
#
#
#
#
#
#  Racing, Simulation, Sports, Multiplayer
#
#
# VR Only Free to Play, Adventure, VR
#
#
# VR Only Adventure, VR, Funny, Free to Play
#
#
#  Action, Indie, Multiplayer, Co-op
#
#
#  Action, Violent, Indie, Shooter
#
#
#  Strategy, World War II, Military, War
#
#
# VR Only Free to Play, Horror, VR
#
#
#  Base Building, Strategy, Zombies, Survival
#
#
#  Metroidvania, RPG, Female Protagonist, Action
#
#
# VR Only Free to Play, Indie, Horror, Psychological Horror
#
#
#  Story Rich, RPG, JRPG, Singleplayer
#
#
#  Simulation, Realistic, Singleplayer, Indie
#
#
# VR Supported Indie, Adventure, Action, VR
#
#
#  Adventure, Action, 3D Platformer, Platformer
#
#
#  FPS, Action, Rogue-lite, Strategy
#
#
#
#
#
#  Adventure, Action, Massively Multiplayer
#
#
#
#
#
#  Action, Violent, Gore, Co-op
#
#
#  RPG, Open World, Post-apocalyptic, Singleplayer
#
#
#  Open World, Action, Multiplayer, Third Person
#
#
#  Great Soundtrack, Story Rich, Female Protagonist, Action
#
#
#  Open World, RPG, Adventure, Singleplayer
#
#
#  FPS, Gore, Action, Shooter
#
#
#  Early Access, Turn-Based Combat, RPG, Dark Fantasy
#
#
#  Survival, Shooter, Multiplayer, Battle Royale
#
#
#  Simulation, Strategy, Action, Military
#
#
#  RPG, Strategy, Indie, Early Access
#
#
#  Action, FPS, Gore, Violent
#
#
#  Stealth, Action, First-Person, Steampunk
#
#
#  FPS, Multiplayer, Online Co-Op, Sci-fi
#
#
#  Massively Multiplayer, RPG, Fantasy, MMORPG
#
#
#  Action, Open World, Multiplayer, First-Person
#
#
# VR Only RPG, Open World, VR, Singleplayer
#
#
#  Action, Adventure, Indie, Metroidvania
#
#
#  FPS, Action, Shooter, Alternate History
#
#
#  Action, Stealth, Adventure, Steampunk
#
#
#  Action, FPS, Open World, Post-apocalyptic
#
#
#  Stealth, First-Person, Action, Assassin
#
#
#  Strategy, Historical, War, Turn-Based Strategy
#
#
#  FPS, Multiplayer, Tactical, Shooter
#
#
#  MMORPG, Massively Multiplayer, RPG, Fantasy
#
#
#  Action, Adventure, Open World, First-Person
#
#
#  Action, FPS, Open World, Post-apocalyptic
#
#
#  Strategy, Turn-Based, Turn-Based Strategy, 4X
#
#
#  Nudity, Sexual Content, Indie, Adventure
#
#
#  Early Access, Simulation, Indie, Early Access
#
#
#  Early Access, Simulation, Strategy, Indie
#
#
# VR Only Action, Gore, Violent, VR
#
#
#  Action, Violent, Gore, Co-op
#
#
#  Early Access, Simulation, Early Access, Strategy
#
#
#  Indie, Strategy, Adventure, Card Game
#
#
#  Action, Indie, Difficult, Adventure
#
#
#  Sexual Content, Casual, Nudity, Violent
#
#
#  Psychological Horror, Psychological, Adventure, Thriller
#
#
#  Indie, Action, Adventure, Pixel Graphics
#
#
#  RPG, Post-apocalyptic, Sci-fi, Isometric
#
#
#  Action, RPG, Survival, Adventure
#
#
#  Simulation, Strategy, Indie, City Builder
#
#
#  Action, Indie, Team-Based, Shooter
#
#
#  Simulation, Adventure, Driving, Open World
#
#
#  Strategy, Board Game, Medieval
#
#
#  Violent, Action, Indie, Adventure
#
#
#  Free to Play, Retro
#
#
#  Strategy, RPG, Indie, Turn-Based
#
#
#  Action, Indie, RPG, Singleplayer
#
#
#  Action
#
#
#  Simulation, Strategy, Nudity, Casual
#
#
#  Simulation, Driving, Realistic, Building
#
#
#  Agriculture, Casual, Simulation, Relaxing
#
#
#  Simulation, Building, Singleplayer, Destruction
#
#
#  Casual, Puzzle, Competitive, Multiplayer
#
#
#
#
#
#  Adventure, RPG, Action, Indie
#
#
#  Adventure, Casual, Violent, Otome
#
#
#  RPG, Open World, Post-apocalyptic, Singleplayer
#
#
#  Open World, Action, Multiplayer, Third Person
#
#
#  Great Soundtrack, Story Rich, Female Protagonist, Action
#
#
#  Survival, Shooter, Multiplayer, Battle Royale
#
#
#  Open World, RPG, Adventure, Singleplayer
#
#
#  FPS, Gore, Action, Shooter
#
#
#  Stealth, Action, First-Person, Steampunk
#
#
#  Action, FPS, Gore, Violent
#
#
#  Stealth, First-Person, Action, Assassin
#
#
# VR Only RPG, Open World, VR, Singleplayer
#
#
#  FPS, Action, Shooter, Alternate History
#
#
#  Action, Stealth, Adventure, Steampunk
#
#
#  Action, FPS, Open World, Post-apocalyptic
#
#
#  Action, FPS, Open World, Post-apocalyptic
#
#
#  Action, Atmospheric, Horror, FPS
#
#
#  RPG, Action, Post-apocalyptic, Open World
#
#
#  Strategy, Turn-Based, Turn-Based Strategy, 4X
#
#
#  RPG, Massively Multiplayer, Dragons, MMORPG
#
#
#  Horror, Survival Horror, Psychological Horror, Action
#
#
#  Early Access, World War II, FPS, Multiplayer
#
#
#  Open World, Post-apocalyptic, Exploration, Singleplayer
#
#
# VR Only VR, Open World, Post-apocalyptic, RPG
#
#
#  Stealth, Action, First-Person, Steampunk
#
#
#  Open World, RPG, Fantasy, Singleplayer
#
#
#  Sci-fi, Space, Singleplayer, Atmospheric
#
#
#  RPG, Massively Multiplayer, Dragons, MMORPG
#
#
#  Open World, RPG, Post-apocalyptic, Singleplayer
#
#
#  Indie, Strategy, Action, Simulation
#
#
#  RPG, Rogue-like, Hack and Slash, Indie
#
#
#  RPG, MMORPG, Open World, Massively Multiplayer

# %%
len(item_details)
# Out:
# 120

# %%
import pandas as pd #makes a dataframe 
test_df = pd.DataFrame({'Game': name_list[:len(reg_price)],
'item_details': item_details[:len(reg_price)],
'reg': reg_price,
'discount price': disc_price
})

# %%
len(item_details[:98])
# Out:
# 98

# %%
test_df
# Out:
#                                                  Game  \
# 0                  Monster Boy and the Cursed Kingdom
# 1                          Survivor Pass 4: Aftermath
# 2   DATE A LIVE: Rio Reincarnation / デート・ア・ライブ 凜緒リ...
# 3                                          Automachef
# 4                           Swords & Souls: Neverseen
# 5                                     Nowhere Prophet
# 6                    Detective Girl of the Steam City
# 7                                                GORN
# 8                                    Streets of Rogue
# 9                               EARTH DEFENSE FORCE 5
# 10                                  RED HOT VENGEANCE
# 11                  FINAL FANTASY XIV: Shadowbringers
# 12                                 Valve Index VR Kit
# 13                  Valve Index Headset + Controllers
# 14                                Valve Index Headset
# 15                       F1® 2019 Anniversary Edition
# 16          Spider-Man: Far From Home Virtual Reality
# 17                                  Aperture Hand Lab
# 18             Totally Reliable Delivery Service Beta
# 19                                    My Friend Pedro
# 20                                   Steel Division 2
# 21                                         The Scream
# 22                                  They Are Billions
# 23                  Bloodstained: Ritual of the Night
# 24                                   Shattered Lights
# 25                                 OCTOPATH TRAVELER™
# 26                                  Cooking Simulator
# 27                          Trover Saves the Universe
# 28                          Kao the Kangaroo: Round 2
# 29                                      Void Bastards
# ..                                                ...
# 70                                          Gun Crazy
# 71             Encased: A Sci-Fi Post-Apocalyptic RPG
# 72                                SKYHILL: Black Mist
# 73                                       Metropolisim
# 74                            Morphies Law: Remorphed
# 75                                       Truck Driver
# 76                           Raiders of the North Sea
# 77            Warhammer 40,000: Inquisitor - Prophecy
# 78                                          RetroArch
# 79                                        Sin Slayers
# 80                            Everreach: Project Eden
# 81                               Mighty Gunvolt Burst
# 82                                     Crossroads Inn
# 83                   Biker Garage: Mechanic Simulator
# 84                                       Farming Life
# 85                              Electrician Simulator
# 86                                     Crystal Crisis
# 87       Face Gasket for Valve Index Headset – 2 Pack
# 88                                       Cat Quest II
# 89                          London Detective Mysteria
# 90                Fallout 4: Game of the Year Edition
# 91                                 Grand Theft Auto V
# 92                                     NieR:Automata™
# 93                      PLAYERUNKNOWN'S BATTLEGROUNDS
# 94        The Elder Scrolls V: Skyrim Special Edition
# 95                                               DOOM
# 96  Dishonored: Death of the Outsider - Deluxe Bundle
# 97                   Wolfenstein II: The New Colossus
# 98                                       Dishonored 2
# 99                     The Elder Scrolls V: Skyrim VR
#
#                                          item_details     reg discount price
# 0         \n Action, Adventure, Indie, Metroidvania\n  $49.99         $34.99
# 1       \n Adventure, Action, Massively Multiplayer\n  $14.99         $11.24
# 2   \n Anime, Visual Novel, Simulation, Sexual Con...  $6.99$           1.40
# 3               \n Indie, Simulation, Funny, Puzzle\n  $39.99         $26.79
# 4                  \n RPG, Action, Adventure, Indie\n  $29.99         $26.99
# 5           \n Strategy, RPG, Card Game, Turn-Based\n   $9.99    No Discount
# 6   \n RPG, Indie, Sexual Content, Female Protagon...  $49.99         $39.99
# 7               \nVR Only VR, Violent, Gore, Action\n  $14.99         $13.49
# 8    \n Rogue-like, Pixel Graphics, Rogue-lite, RPG\n  $14.99         $13.49
# 9   \n Action, Third-Person Shooter, Online Co-Op,...  $24.99         $22.49
# 10            \n Free to Play, Indie, Violent, Gore\n  $14.99         $11.99
# 11   \n Massively Multiplayer, RPG, Fantasy, MMORPG\n  $19.99         $14.99
# 12                                              \n \n  $19.99    No Discount
# 13                                              \n \n  $59.99    No Discount
# 14                                              \n \n    Free    No Discount
# 15       \n Racing, Simulation, Sports, Multiplayer\n  $39.99    No Discount
# 16            \nVR Only Free to Play, Adventure, VR\n  $999.0              0
# 17     \nVR Only Adventure, VR, Funny, Free to Play\n  $749.0              0
# 18             \n Action, Indie, Multiplayer, Co-op\n  $499.0              0
# 19               \n Action, Violent, Indie, Shooter\n  $59.99    No Discount
# 20         \n Strategy, World War II, Military, War\n    Free    No Discount
# 21               \nVR Only Free to Play, Horror, VR\n    Free    No Discount
# 22    \n Base Building, Strategy, Zombies, Survival\n    Free    No Discount
# 23  \n Metroidvania, RPG, Female Protagonist, Acti...  $19.99    No Discount
# 24  \nVR Only Free to Play, Indie, Horror, Psychol...  $39.99    No Discount
# 25           \n Story Rich, RPG, JRPG, Singleplayer\n    Free    No Discount
# 26    \n Simulation, Realistic, Singleplayer, Indie\n  $29.99    No Discount
# 27      \nVR Supported Indie, Adventure, Action, VR\n  $39.99    No Discount
# 28  \n Adventure, Action, 3D Platformer, Platformer\n    Free    No Discount
# 29             \n FPS, Action, Rogue-lite, Strategy\n  $59.99    No Discount
# ..                                                ...     ...            ...
# 70      \n Indie, Action, Adventure, Pixel Graphics\n  $59.99         $14.99
# 71      \n RPG, Post-apocalyptic, Sci-fi, Isometric\n  $29.99         $14.99
# 72              \n Action, RPG, Survival, Adventure\n  $39.99         $26.79
# 73     \n Simulation, Strategy, Indie, City Builder\n  $29.99         $14.99
# 74            \n Action, Indie, Team-Based, Shooter\n  $39.99         $13.19
# 75    \n Simulation, Adventure, Driving, Open World\n  $19.99          $6.59
# 76                \n Strategy, Board Game, Medieval\n  $59.99         $11.99
# 77             \n Violent, Action, Indie, Adventure\n  $59.99         $19.79
# 78                           \n Free to Play, Retro\n  $39.99          $7.99
# 79              \n Strategy, RPG, Indie, Turn-Based\n  $59.99         $19.79
# 80              \n Action, Indie, RPG, Singleplayer\n  $29.99          $9.89
# 81                                        \n Action\n  $79.99         $23.99
# 82          \n Simulation, Strategy, Nudity, Casual\n  $59.99         $29.99
# 83      \n Simulation, Driving, Realistic, Building\n  $59.99         $29.99
# 84     \n Agriculture, Casual, Simulation, Relaxing\n  $39.99          $7.99
# 85  \n Simulation, Building, Singleplayer, Destruc...  $19.99          $4.99
# 86      \n Casual, Puzzle, Competitive, Multiplayer\n  $39.99         $29.99
# 87                                              \n \n  $39.99         $25.99
# 88                 \n Adventure, RPG, Action, Indie\n  $59.99         $14.99
# 89             \n Adventure, Casual, Violent, Otome\n  $29.99         $25.49
# 90  \n RPG, Open World, Post-apocalyptic, Singlepl...  $29.99          $7.49
# 91  \n Open World, Action, Multiplayer, Third Pers...  $59.99         $14.99
# 92  \n Great Soundtrack, Story Rich, Female Protag...  $29.99          $5.99
# 93  \n Survival, Shooter, Multiplayer, Battle Roya...  $19.99          $6.59
# 94      \n Open World, RPG, Adventure, Singleplayer\n  $29.99          $5.99
# 95                    \n FPS, Gore, Action, Shooter\n  $39.99         $25.99
# 96      \n Stealth, Action, First-Person, Steampunk\n  $19.99          $4.99
# 97                    \n Action, FPS, Gore, Violent\n  $14.99         $11.24
# 98       \n Stealth, First-Person, Action, Assassin\n  $6.99$           1.40
# 99      \nVR Only RPG, Open World, VR, Singleplayer\n  $19.99          $9.99
#
# [100 rows x 4 columns]

# %% [markdown]
# Additional Resources:
# https://www.dataquest.io/blog/web-scraping-beautifulsoup/
#
# https://www.geeksforgeeks.org/implementing-web-scraping-python-beautiful-soup/
#
# https://www.youtube.com/watch?v=ng2o98k983k
